# %% [markdown]
# # Tokenization
#
# This notebook shows how the word-level tokenizer splits text into tokens and IDs.

# %%
from src.tokenizer import WordTokenizer

text = 'Banks turn deposits into loans.'
tokenizer = WordTokenizer().fit(text)
tokens = tokenizer.tokenize(text)
ids = tokenizer.encode(text)
tokens, ids
