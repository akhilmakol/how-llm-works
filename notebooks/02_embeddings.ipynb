# %% [markdown]
# # Embeddings
#
# This notebook inspects token and positional embeddings.

# %%
import torch
from src.embeddings import TokenPositionalEmbedding

embedding = TokenPositionalEmbedding(vocab_size=20, d_model=8, block_size=6)
x = torch.tensor([[1, 2, 3, 4]])
embedding(x).shape
