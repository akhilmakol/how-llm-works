# %% [markdown]
# # Transformer Block
#
# This notebook shows one transformer block processing token embeddings.

# %%
import torch
from src.transformer import TransformerBlock

block = TransformerBlock(d_model=8, n_heads=2, d_ff=16)
x = torch.randn(2, 5, 8)
y, weights = block(x)
y.shape, weights.shape
