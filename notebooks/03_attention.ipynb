# %% [markdown]
# # Attention
#
# This notebook runs causal self-attention on a small random tensor.

# %%
import torch
from src.attention import CausalSelfAttention

attention = CausalSelfAttention(d_model=8, n_heads=2)
x = torch.randn(1, 4, 8)
context, weights = attention(x)
context.shape, weights.shape
